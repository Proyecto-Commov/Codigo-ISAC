# %%
import numpy as np
import matplotlib.pyplot as plt

from config import PipelineConfig
from signal_types import SignalBlock
from main_pipeline import MicroDopplerPipeline

# %%
cfg = PipelineConfig(
    n_subcarriers=128,
    cp_len=16,
    n_symbols_per_frame=32,
    sample_rate=1e6,
    carrier_freq=3.5e9,
)
pipe = MicroDopplerPipeline(cfg)
